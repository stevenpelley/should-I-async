# %%
from matplotlib import pyplot as plt
import numpy
import math
import sqlite3
# %matplotlib inline

con = sqlite3.connect("pt.db")
cur = con.cursor()
res = cur.execute("""
                  select * from samples_view limit 10;
                  """)
print(res.fetchall())

fig = plt.figure()
x = numpy.arange(0, math.pi*2, 0.05)
y = numpy.sin(x)
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y)
#plt.show()
# Out:
# [(0, 0, 0, -1, -1, 'unknown', 'unknown', '0', 'unknown', 0, 'unknown', '0', 'unknown', 0, 'unknown', 'no branch', 0, 0, 0, 0.0, 0), (1, 259034356306612, 0, 194955, 194955, 'csgb', 'psb', 'ffffffffa76dcfd3', 'skb_copy_datagram_from_iter', 83, '[kernel.kallsyms]', '0', 'unknown', 0, 'unknown', 'no branch', 0, 0, 0, 0.0, 0), (2, 259034356306612, 0, 194955, 194955, 'csgb', 'cbr', 'ffffffffa76dcfd3', 'skb_copy_datagram_from_iter', 83, '[kernel.kallsyms]', '0', 'unknown', 0, 'unknown', 'no branch', 0, 0, 0, 0.0, 0), (3, 259034356306612, 0, 194955, 194955, 'csgb', 'branches', 'ffffffffa76dcfe0', 'skb_copy_datagram_from_iter', 96, '[kernel.kallsyms]', 'ffffffffa6cd4140', '__check_object_size', 0, '[kernel.kallsyms]', 'call', 0, 0, 0, 0.0, 3), (4, 259034356306738, 0, 194955, 194955, 'csgb', 'branches', 'ffffffffa6cd414a', '__check_object_size', 10, '[kernel.kallsyms]', 'ffffffffa6cd4157', '__check_object_size', 23, '[kernel.kallsyms]', 'conditional jump', 0, 9, 56, 0.16, 9), (5, 259034356306738, 0, 194955, 194955, 'csgb', 'branches', 'ffffffffa6cd415e', '__check_object_size', 30, '[kernel.kallsyms]', 'ffffffffa6cd3fe0', '__check_object_size.part.0', 0, '[kernel.kallsyms]', 'call', 0, 0, 0, 0.0, 3), (6, 259034356306738, 0, 194955, 194955, 'csgb', 'branches', 'ffffffffa6cd4015', '__check_object_size.part.0', 53, '[kernel.kallsyms]', 'ffffffffa6cd3c90', 'check_stack_object', 0, '[kernel.kallsyms]', 'call', 0, 0, 0, 0.0, 3), (7, 259034356306738, 0, 194955, 194955, 'csgb', 'branches', 'ffffffffa6cd3ca8', 'check_stack_object', 24, '[kernel.kallsyms]', 'ffffffffa6cd3d0b', 'check_stack_object', 123, '[kernel.kallsyms]', 'conditional jump', 0, 0, 0, 0.0, 9), (8, 259034356306743, 0, 194955, 194955, 'csgb', 'branches', 'ffffffffa6cd3d18', 'check_stack_object', 136, '[kernel.kallsyms]', 'ffffffffa6cd401a', '__check_object_size.part.0', 58, '[kernel.kallsyms]', 'return', 0, 34, 17, 2.0, 5), (9, 259034356306744, 0, 194955, 194955, 'csgb', 'branches', 'ffffffffa6cd401c', '__check_object_size.part.0', 60, '[kernel.kallsyms]', 'ffffffffa6cd4044', '__check_object_size.part.0', 100, '[kernel.kallsyms]', 'conditional jump', 0, 2, 1, 2.0, 9)]
